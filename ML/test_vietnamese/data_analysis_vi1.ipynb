# %%
# %pip install wordcloud
# %pip install seaborn
# %pip install matplotlib
# %pip install numpy
# %pip install pandas
# Out:
# Requirement already satisfied: wordcloud in c:\users\ncpc\.conda\envs\prjnckh\lib\site-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\ncpc\appdata\roaming\python\python310\site-packages (from wordcloud) (2.2.3)
# Requirement already satisfied: pillow in c:\users\ncpc\.conda\envs\prjnckh\lib\site-packages (from wordcloud) (11.1.0)
# Requirement already satisfied: matplotlib in c:\users\ncpc\.conda\envs\prjnckh\lib\site-packages (from wordcloud) (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ncpc\.conda\envs\prjnckh\lib\site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\ncpc\.conda\envs\prjnckh\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ncpc\.conda\envs\prjnckh\lib\site-packages (from matplotlib->wordcloud) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ncpc\.conda\envs\prjnckh\lib\site-packages (from matplotlib->wordcloud) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\ncpc\.conda\envs\prjnckh\lib\site-packages (from matplotlib->wordcloud) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ncpc\.conda\envs\prjnckh\lib\site-packages (from matplotlib->wordcloud) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ncpc\.conda\envs\prjnckh\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\ncpc\.conda\envs\prjnckh\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: seaborn in c:\users\ncpc\.conda\envs\prjnckh\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\ncpc\appdata\roaming\python\python310\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: pandas>=1.2 in c:\users\ncpc\.conda\envs\prjnckh\lib\site-packages (from seaborn) (2.3.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\ncpc\.conda\envs\prjnckh\lib\site-packages (from seaborn) (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ncpc\.conda\envs\prjnckh\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\ncpc\.conda\envs\prjnckh\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ncpc\.conda\envs\prjnckh\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ncpc\.conda\envs\prjnckh\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\ncpc\.conda\envs\prjnckh\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\ncpc\.conda\envs\prjnckh\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ncpc\.conda\envs\prjnckh\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ncpc\.conda\envs\prjnckh\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ncpc\.conda\envs\prjnckh\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ncpc\.conda\envs\prjnckh\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\ncpc\.conda\envs\prjnckh\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in c:\users\ncpc\.conda\envs\prjnckh\lib\site-packages (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ncpc\.conda\envs\prjnckh\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\ncpc\.conda\envs\prjnckh\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ncpc\.conda\envs\prjnckh\lib\site-packages (from matplotlib) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ncpc\.conda\envs\prjnckh\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\ncpc\appdata\roaming\python\python310\site-packages (from matplotlib) (2.2.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\ncpc\.conda\envs\prjnckh\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\ncpc\.conda\envs\prjnckh\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ncpc\.conda\envs\prjnckh\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ncpc\.conda\envs\prjnckh\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\ncpc\.conda\envs\prjnckh\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in c:\users\ncpc\appdata\roaming\python\python310\site-packages (2.2.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in c:\users\ncpc\.conda\envs\prjnckh\lib\site-packages (2.3.0)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\ncpc\appdata\roaming\python\python310\site-packages (from pandas) (2.2.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ncpc\.conda\envs\prjnckh\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ncpc\.conda\envs\prjnckh\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ncpc\.conda\envs\prjnckh\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\ncpc\.conda\envs\prjnckh\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
import numpy as np
from wordcloud import WordCloud
import pandas as pd
import matplotlib.pyplot as plt
import string
import re
from collections import Counter

#đọc file
file_path = "./dataset_vi/Amazon_Product_Review_full_vi_cleaned.csv"
df = pd.read_csv(file_path)
# Xác định cột chứa nội dung review: ưu tiên 'review_body', sau đó 'review_headline'
if 'review_body' in df.columns:
    review_col = 'review_body'
elif 'review_headline' in df.columns:
    review_col = 'review_headline'
else:
    raise Exception("Không tìm thấy cột review (expected 'review_body', 'review_headline')")

# %%
print("=== Thông tin dataset ===")
df.info()
# Out:
# === Thông tin dataset ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10108 entries, 0 to 10107
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   marketplace        10108 non-null  object
#  1   customer_id        10108 non-null  int64
#  2   review_id          10108 non-null  object
#  3   product_id         10108 non-null  object
#  4   product_parent     10108 non-null  int64
#  5   product_title      10108 non-null  object
#  6   product_category   10108 non-null  object
#  7   star_rating        10108 non-null  int64
#  8   helpful_votes      10108 non-null  int64
#  9   total_votes        10108 non-null  int64
#  10  vine               10108 non-null  object
#  11  verified_purchase  10108 non-null  object
#  12  review_headline    10108 non-null  object
#  13  review_body        10108 non-null  object
#  14  review_date        10108 non-null  object
#  15  sentiment          10108 non-null  int64
# dtypes: int64(6), object(10)
# memory usage: 1.2+ MB

# %%
#Kiểm tra dữ liệu trùng lặp
duplicates = df.duplicated().sum()
print(f"\nSố dòng dữ liệu trùng lặp: {duplicates}")
# Out:
# Số dòng dữ liệu trùng lặp: 0

# %%
# Kiểm tra số lượng giá trị null theo từng cột
print("\nSố lượng giá trị null theo cột:")
print(df.isnull().sum())
# Out:
# Số lượng giá trị null theo cột:
# marketplace          0
# customer_id          0
# review_id            0
# product_id           0
# product_parent       0
# product_title        0
# product_category     0
# star_rating          0
# helpful_votes        0
# total_votes          0
# vine                 0
# verified_purchase    0
# review_headline      0
# review_body          0
# review_date          0
# sentiment            0
# dtype: int64

# %%
import numpy as np

cols_to_numeric = ['star_rating', 'helpful_votes', 'total_votes']  # sửa lại 'sentiment' nếu đúng tên cột
# Chuyển các cột này về kiểu số nếu có trong DataFrame
for col in cols_to_numeric:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce')

# Lọc ra đúng các cột có trong DataFrame và là số
selected_cols = [col for col in cols_to_numeric if col in df.columns]
print("Các cột được chọn để vẽ heatmap:", selected_cols)

if selected_cols:
    plt.figure(figsize=(8,6))
    corr = df[selected_cols].corr()
    sns.heatmap(corr, annot=True, cmap='coolwarm')
    plt.title("Heatmap tương quan giữa các biến số được chọn")
    plt.show()
else:
    print("Không có cột số nào để vẽ heatmap.")
# Out:
# Các cột được chọn để vẽ heatmap: ['star_rating', 'helpful_votes', 'total_votes']

# %%
# 1. Phân loại star_rating theo product_category
# -------------------------------

plt.figure(figsize=(12,6))
sns.countplot(data=df, x='product_category', hue='star_rating')
plt.title('Phân loại star_rating theo product_category')
plt.xlabel('Product Category')
plt.ylabel('Số lượng đánh giá')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# 1. Phân tích mối quan hệ giữa star_rating và review_body
# Biểu đồ đếm số lượng review theo từng star_rating
plt.figure(figsize=(8, 6))
sns.countplot(x='star_rating', data=df, palette='viridis')
plt.title('Số lượng review theo star_rating')
plt.xlabel('Star Rating')
plt.ylabel('Số lượng review')
plt.show()
# Out:
# C:\Users\NCPC\AppData\Local\Temp\ipykernel_18468\2769464641.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='star_rating', data=df, palette='viridis')

# %%
plt.figure(figsize=(6,6))
df['sentiment'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, cmap='cool')
plt.title("Tỉ lệ các loại sentiment trong review")
plt.ylabel("")
plt.show()

# %%
import re
import string
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns

# Danh sách stopwords cơ bản (bạn có thể mở rộng danh sách này nếu cần)
default_stopwords = set(["the", "and", "a", "an", "in", "of", "to", "is", "it", "that", "for", "with", "on", "this"])

# Hàm tokenize: chuyển văn bản về chữ thường, loại bỏ dấu câu và stopwords
def tokenize(text):
    text = str(text).lower()  # chuyển về chữ thường
    text = re.sub(f"[{re.escape(string.punctuation)}]", " ", text)  # loại bỏ dấu câu
    tokens = text.split()
    tokens = [t for t in tokens if t not in default_stopwords]  # loại bỏ stopwords
    return tokens

# Lấy danh sách các sentiment có trong dữ liệu
sentiments = sorted(df["sentiment"].dropna().unique())
word_freq_dict = {}

for s in sentiments:
    # Lấy các review tương ứng với sentiment s
    texts = df[df['sentiment'] == s]["review_body"].dropna().tolist()
    all_tokens = []
    for text in texts:
        all_tokens.extend(tokenize(text))
    # Đếm tần suất từ
    counter = Counter(all_tokens)
    common_words = counter.most_common(10)  # Lấy 10 từ xuất hiện nhiều nhất
    word_freq_dict[s] = common_words

# Vẽ biểu đồ cho từng loại sentiment
num_sentiments = len(sentiments)
fig, axes = plt.subplots(num_sentiments, 1, figsize=(10, 5 * num_sentiments))
if num_sentiments == 1:
    axes = [axes]

for i, s in enumerate(sentiments):
    if word_freq_dict[s]:
        words, counts = zip(*word_freq_dict[s])
    else:
        words, counts = ([], [])
    sns.barplot(x=list(counts), y=list(words), ax=axes[i], palette="cool")
    axes[i].set_title(f"Top 10 từ thường gặp với sentiment '{s}'")
    axes[i].set_xlabel("Tần Số")
    axes[i].set_ylabel("Từ")

plt.tight_layout()
plt.show()
# Out:
# C:\Users\NCPC\AppData\Local\Temp\ipykernel_18468\386421398.py:44: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(counts), y=list(words), ax=axes[i], palette="cool")
# C:\Users\NCPC\AppData\Local\Temp\ipykernel_18468\386421398.py:44: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(counts), y=list(words), ax=axes[i], palette="cool")
